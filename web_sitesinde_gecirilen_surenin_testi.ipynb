# %% [markdown]
# ## PROBLEM

# %% [markdown]
# ## Web sitemizde geçirilen ort süre gerçekten 170 sn mi?

# %% [markdown]
# * Yazılımlardan elde edilen web sitesinde geçirilen ort. süreler var.
# * Bu veriler incelendiğinde bir yönetici ya da çalışan bu değerlerin böyle olmadığına yönelk düşünceler taşıyor ve bu durumu test etmek istiyorlar.

# %%
import numpy as np

# %%
olcumler=np.array([17, 160, 234, 149, 145, 107, 197, 75, 201, 225, 211, 119,157, 145, 127, 244, 163, 114, 145,  65, 112, 185, 202, 146,203, 224, 203, 114, 188, 156, 187, 154, 177, 95, 165, 50, 110, 216, 138, 151, 166, 135, 155, 84, 251, 173, 131, 207, 121, 120])

# %%
olcumler[0:5]
# Out:
# array([ 17, 160, 234, 149, 145])

# %%
import scipy.stats as stats

# %%
stats.describe(olcumler)
# Out:
# DescribeResult(nobs=50, minmax=(17, 251), mean=154.38, variance=2578.0363265306123, skewness=-0.32398897278694483, kurtosis=-0.05849823498415985)

# %% [markdown]
# **Grafik inceleme yöntemleri ile hipotezin testi**

# %% [markdown]
# _histogram_

# %%
pd.DataFrame(olcumler).plot.hist();

# %% [markdown]
# _qqplot_

# %%
import pylab
stats.probplot(olcumler,dist="norm",plot=pylab)
pylab.show()

# %% [markdown]
# **Shapiro-Wilks Testi ile hipotezin testi**

# %% [markdown]
# H:0 örnek dağılım ile teorik normal dağılım arasında fark yok
#
#
# H:1 örnek dağılım ile teorik normal dağılım arasında fark var

# %%
from scipy.stats import shapiro

# %%
shapiro(olcumler)
# Out:
# ShapiroResult(statistic=0.9853101372718811, pvalue=0.7848551869392395)

# %% [markdown]
# **pvalue>0.05 H:0 reddedilemez**

# %% [markdown]
# ## T TESTİ

# %%
stats.ttest_1samp(olcumler,popmean=170)
# Out:
# TtestResult(statistic=-2.1753117985877966, pvalue=0.034460415195071446, df=49)

# %% [markdown]
# H0: Web sitede geçirilen ort süre 170'tir
#
# H1: Web sitede geçirilen ort süre 170 değildir.
#
# **pvalue<0.05 yani  H0 hipotezi reddedilir**

# %% [markdown]
# ## Nonparametrik Tek Örneklem Testi

# %%
from statsmodels.stats.descriptivestats import sign_test

# %%
sign_test(olcumler,170)
# Out:
# (-7.0, 0.06490864707227217)
